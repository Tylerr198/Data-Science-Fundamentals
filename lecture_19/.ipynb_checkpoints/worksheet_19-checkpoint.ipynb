# %% [markdown]
# # Worksheet 19
#
# Name: Tyler Nguyen
# UID: U13947916
#
# ### Topics
#
# - Linear Model Evaluation
#
# ## Linear Model Evaluation
#
# Notice that R^2 only increases with the number of explanatory variables used. Hence the need for an adjusted R^2 that penalizes for insignificant explanatory variables.

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

SAMPLE_SIZE = 100
beta = [1, 5]
X = -10.0 + 10.0 * np.random.random(SAMPLE_SIZE)
Y = beta[0] + beta[1] * X + np.random.randn(SAMPLE_SIZE)

for i in range(1, 15):
    X_transform = PolynomialFeatures(degree=i, include_bias=False).fit_transform(X.reshape(-1, 1))
    model = LinearRegression()
    model.fit(X_transform, Y)
    print(model.score(X_transform, Y))
# Out:
# 0.9954869266547971
# 0.9955305512354063
# 0.9955477261725098
# 0.9956007503141207
# 0.9956631904923746
# 0.9956663269211427
# 0.9956720529158568
# 0.9956799294801373
# 0.9957433766654563
# 0.9958035654786055
# 0.9959155431086545
# 0.9959614643152972
# 0.995988634659405
# 0.9958451474386636

# %% [markdown]
# a) Hypothesis Testing Sandbox (follow along in class) [Notes](https://medium.com/@gallettilance/hypothesis-testing-almost-everything-you-need-to-know-ce812ded50b)

# %%
import numpy as np
from scipy.stats import binom
import matplotlib.pyplot as plt

flips = [1, 0, 0, 1, 0]

def num_successes(flips):
    return sum(flips)

print(binom.pmf(num_successes(flips), len(flips), 1/2))

SAMPLE_SIZE = 5
flips = [np.random.choice([0, 1]) for _ in range(SAMPLE_SIZE)]
print(flips)
print(binom.pmf(num_successes(flips), SAMPLE_SIZE, 1/2))

p_est = []

for _ in range(1000):
    flips = [np.random.choice([0, 1]) for _ in range(SAMPLE_SIZE)]
    p_est.append(sum(flips) / SAMPLE_SIZE)

fig, ax = plt.subplots()
_, bins, patches = ax.hist(p_est, bins=SAMPLE_SIZE + 1)
p = np.digitize([2/5], bins)
patches[p[0]-1].set_facecolor('r')
ax.bar_label(patches)
plt.show()
# Out:
# 0.3124999999999998
# [0, 1, 0, 1, 0]
# 0.3124999999999998

# %% [markdown]
# b) Plot a data set and fitted line through the point when there is no relationship between X and y.

# %%
import numpy as np
import matplotlib.pyplot as plt

SAMPLE_SIZE = 10

xlin = -1.0 + 1.0 * np.random.random(SAMPLE_SIZE)
y = 0.0 * xlin + np.random.randn(SAMPLE_SIZE)

intercept = np.ones(np.shape(xlin)[0])
X = np.array([intercept, xlin]).T
beta = np.linalg.inv(X.T @X) @ X.T @y

xplot = np.linspace(-1,1,20)
yestplot = beta[0] + beta[1] * xplot
plt.plot(xplot, yestplot,'b-',lw=2)
plt.plot(xlin, y,'ro',markersize=4)
plt.show()

# %% [markdown]
# c) Using the above code, plot a histogram of the parameter estimates for the slope after generating `1000` independent datasets. Comment on what the plot means. Increase the sample size to see what happens to the plot. Explain.

# %%
beta_hist = []
NUM_TRIALS = 10000
SAMPLE_SIZE = 10
for _ in range(NUM_TRIALS):
    xlin = -1.0 + 1.0 * np.random.random(SAMPLE_SIZE)
    y = 0.0 * xlin + np.random.randn(SAMPLE_SIZE)
    
    intercept = np.ones(np.shape(xlin)[0])
    X = np.array([intercept, xlin]).T
    beta = np.linalg.inv(X.T @X) @ X.T @y
    beta_hist.append(beta[1])


fig, ax = plt.subplots()
ax.hist(beta_hist, bins=100, density=True)
plt.show()

# %% [markdown]
# As you increase the sample size, the distribution of beta becomes more consistent. We can then better prove that there is a relationship between X and Y.

# %% [markdown]
# d) We know that:
#
# $$\hat\beta-\beta \sim \mathcal{N}(0,\sigma^2 (X^TX)^{-1})$$
#
# thus for each component $k$ of $\hat\beta$ (here there are only two - one slope and one intercept)
#
# $$\hat\beta_k -\beta_k \sim \mathcal{N}(0, \sigma^2 S_{kk})$$
#
# where $S_{kk}$ is the $k^\text{th}$ diagonal element of $(X^TX)^{-1}$. Thus, we know that
#
# $$z_k = \frac{\hat\beta_k -\beta_k}{\sqrt{\sigma^2 S_{kk}}} \sim \mathcal{N}(0,1)$$
#
# Verify that this is the case through a simulation and compare it to the standard normal pdf by plotting it on top of the histogram.

# %%
from scipy.stats import norm


# Assuming you have values for the following parameters
sigma_squared = 1.0  # Variance of the error term in the regression model
S_kk = 1.0  # Diagonal element k of the covariance matrix S
beta_k = 0.0  # True value of coefficient beta_k
beta_hat_k_hist = []  # List to store simulated values of beta_hat_k
beta_hist = []
for _ in range(1000):
    # Simulate beta_hat_k using normal distribution with mean beta_k and standard deviation sqrt(sigma^2 S_kk)
    beta_hat_k = np.random.normal(beta_k, np.sqrt(sigma_squared * S_kk))
    beta_hist.append(beta_hat_k)

xs = np.linspace(-10,10,1000)
fig, ax = plt.subplots()
ax.hist(beta_hist, bins=100, density=True)
# Plot standard normal pdf
ax.plot(xs, norm.pdf(xs, 0, np.sqrt(sigma_squared * S_kk)), color='green', label='Standard Normal PDF')
plt.show()

# %% [markdown]
# e) Above we normalized $\hat\beta$ by subtracting the mean and dividing by the standard deviation. While we know that the estimate of beta is an unbiased estimator, we don't know the standard deviation. So in practice when doing a hypothesis test where we want to assume that $\beta = 0$, we can simply use $\hat\beta$ in the numerator. However we don't know the standard deviation and need to use an unbiased estimate of the standard deviation instead. This estimate is the standard error `s`
#
# $$s = \sqrt{\frac{RSS}{n - p}}$$
#
# where p is the number of parameters beta (here there are 2 - one slope and one intercept). This normalized $\hat\beta$ can be shown to follow a t-distribution with `n-p` degrees of freedom. Verify this is the case with a simulation.

# %%
from scipy.stats import t

# Assuming you have values for the following parameters
n = 100  # Sample size
p = 2    # Number of parameters in the regression model (including intercept)
SAMPLE_SIZE = n - p  # Degrees of freedom for the t-distribution

# Generate some sample data for ytrue and ypred
ytrue = np.random.normal(0, 1, n)  # Simulating true values with mean 0 and standard deviation 1
ypred = np.random.normal(0, 1, n)  # Simulating predicted values with mean 0 and standard deviation 1

# Function to calculate standard error
def standard_error(ytrue, ypred):
    RSS = np.sum((ytrue - ypred) ** 2)  # Residual Sum of Squares
    return np.sqrt(RSS / (n - p))

# Simulate normalized beta_hat values
beta_hist = []
for _ in range(1000):
    se = standard_error(ytrue, ypred)
    beta_hat = np.random.normal(0, se)  # Simulating beta_hat using a normal distribution with mean 0 and standard deviation se
    beta_hist.append(beta_hat)

xs = np.linspace(-10,10,1000)
fig, ax = plt.subplots()
ax.hist(beta_hist, bins=100, density=True)
ax.plot(xs, t.pdf(xs, SAMPLE_SIZE - 2), color='red')
plt.show()

# %% [markdown]
# f) You are given the following dataset:

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([-0.1920605, -0.11290798, -0.56434374, -0.67052057, -0.19233284, -0.42403586, -0.8114285, -0.38986946, -0.37384161, -0.50930229])
y = np.array([-0.34063108, -0.33409286, 0.34245857, 0.11062295, 0.76682389, 0.86592388, -1.68912015, -2.01463592, 1.61798563, 0.60557414])

intercept = np.ones(np.shape(x)[0])
X = np.array([intercept, x]).T
beta_hat = np.linalg.inv(X.T @ X) @ X.T @ y

print(beta_hat)

xplot = np.linspace(-1,.25,20)
yestplot = beta_hat[0] + beta_hat[1] * xplot
plt.plot(xplot, yestplot,'b-',lw=2)
plt.plot(x, y,'ro',markersize=4)
plt.show()
# Out:
# [0.50155603 1.19902827]

# %% [markdown]
# what is the probability of observing a dataset at least as extreme as the above assuming $\beta = 0$ ?

# %%
# Residuals
residuals = y - X @ beta_hat

# Standard error of the slope coefficient
SE_beta_1 = np.sqrt(np.sum(residuals ** 2) / (len(x) - 2)) / np.sqrt(np.sum((x - np.mean(x)) ** 2))

# T-statistic
t_statistic = beta_hat[1] / SE_beta_1

# Degrees of freedom
df = len(x) - 2

# Calculate p-value
p_value = 2 * (1 - t.cdf(abs(t_statistic), df))

print("p-value:", p_value)
# Out:
# p-value: 0.513142072090575
